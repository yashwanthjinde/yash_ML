# %%
import pandas as pd 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
wc=pd.read_csv(r'C:\Users\Narasimha\yashdata\statups.csv')

# %%
wc
# Out:
#             x          y          z           w          p
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
wc.head()
# Out:
#            x          y          z           w          p
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
wc=wc.drop(['w'],axis=1)

# %%
wc
# Out:
#             x          y          z          p
# 0   165349.20  136897.80  471784.10  192261.83
# 1   162597.70  151377.59  443898.53  191792.06
# 2   153441.51  101145.55  407934.54  191050.39
# 3   144372.41  118671.85  383199.62  182901.99
# 4   142107.34   91391.77  366168.42  166187.94
# 5   131876.90   99814.71  362861.36  156991.12
# 6   134615.46  147198.87  127716.82  156122.51
# 7   130298.13  145530.06  323876.68  155752.60
# 8   120542.52  148718.95  311613.29  152211.77
# 9   123334.88  108679.17  304981.62  149759.96
# 10  101913.08  110594.11  229160.95  146121.95
# 11  100671.96   91790.61  249744.55  144259.40
# 12   93863.75  127320.38  249839.44  141585.52
# 13   91992.39  135495.07  252664.93  134307.35
# 14  119943.24  156547.42  256512.92  132602.65
# 15  114523.61  122616.84  261776.23  129917.04
# 16   78013.11  121597.55  264346.06  126992.93
# 17   94657.16  145077.58  282574.31  125370.37
# 18   91749.16  114175.79  294919.57  124266.90
# ...

# %%
wc.head()
# Out:
#            x          y          z          p
# 0  165349.20  136897.80  471784.10  192261.83
# 1  162597.70  151377.59  443898.53  191792.06
# 2  153441.51  101145.55  407934.54  191050.39
# 3  144372.41  118671.85  383199.62  182901.99
# 4  142107.34   91391.77  366168.42  166187.94

# %%
wc.shape
# Out:
# (50, 4)

# %%
wc.corr()
# Out:
#           x         y         z         p
# x  1.000000  0.241955  0.724248  0.972900
# y  0.241955  1.000000 -0.032154  0.200717
# z  0.724248 -0.032154  1.000000  0.747766
# p  0.972900  0.200717  0.747766  1.000000

# %%
type(wc)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.pairplot(wc.iloc[:,:])

# %%
sns.pairplot(wc.iloc[1:4])

# %%
import statsmodels.formula.api as smf

# %%
ml1=smf.ols('p ~ x+y+z',data=wc).fit()
ml1.params
# Out:
# Intercept    50122.192990
# x                0.805715
# y               -0.026816
# z                0.027228
# dtype: float64

# %%
ml1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      p   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Sat, 10 Aug 2019   Prob (F-statistic):           4.53e-30
# Time:                        10:52:16   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %%
ml2=smf.ols('p ~ y',data=wc).fit()
ml2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      p   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     2.015
# Date:                Sat, 10 Aug 2019   Prob (F-statistic):              0.162
# Time:                        10:52:16   Log-Likelihood:                -599.63
# No. Observations:                  50   AIC:                             1203.
# Df Residuals:                      48   BIC:                             1207.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7.697e+04   2.53e+04      3.040      0.004    2.61e+04    1.28e+05
# ...

# %%
ml3=smf.ols('p ~ z',data=wc).fit()
ml3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      p   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     60.88
# Date:                Sat, 10 Aug 2019   Prob (F-statistic):           4.38e-10
# Time:                        10:52:16   Log-Likelihood:                -580.18
# No. Observations:                  50   AIC:                             1164.
# Df Residuals:                      48   BIC:                             1168.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept       6e+04   7684.530      7.808      0.000    4.46e+04    7.55e+04
# ...

# %%
ml4=smf.ols('p ~ y+z',data=wc).fit()
ml4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      p   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.593
# Method:                 Least Squares   F-statistic:                     36.71
# Date:                Sat, 10 Aug 2019   Prob (F-statistic):           2.50e-10
# Time:                        10:52:16   Log-Likelihood:                -577.13
# No. Observations:                  50   AIC:                             1160.
# Df Residuals:                      47   BIC:                             1166.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.022e+04   1.77e+04      1.143      0.259   -1.54e+04    5.58e+04
# ...

# %%
import statsmodels.api as sm
sm.graphics.influence_plot(ml1)

# %%
wc1=wc.drop(wc.index[[49,48]],axis=0,inplace=False)

# %%
wc1.tail(25)
# Out:
#            x          y          z          p
# 23  67532.53  105751.03  304768.73  108733.99
# 24  77044.01   99281.34  140574.81  108552.04
# 25  64664.71  139553.16  137962.62  107404.34
# 26  75328.87  144135.98  134050.07  105733.54
# 27  72107.60  127864.55  353183.81  105008.31
# 28  66051.52  182645.56  118148.20  103282.38
# 29  65605.48  153032.06  107138.38  101004.64
# 30  61994.48  115641.28   91131.24   99937.59
# 31  61136.38  152701.92   88218.23   97483.56
# 32  63408.86  129219.61   46085.25   97427.84
# 33  55493.95  103057.49  214634.81   96778.92
# 34  46426.07  157693.92  210797.67   96712.80
# 35  46014.02   85047.44  205517.64   96479.51
# 36  28663.76  127056.21  201126.82   90708.19
# 37  44069.95   51283.14  197029.42   89949.14
# 38  20229.59   65947.93  185265.10   81229.06
# 39  38558.51   82982.09  174999.30   81005.76
# 40  28754.33  118546.05  172795.67   78239.91
# 41  27892.92   84710.77  164470.71   77798.83
# ...

# %%
m1_new=smf.ols('p ~ x+y+z',data=wc1).fit()
m1_new.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      p   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     378.3
# Date:                Sat, 10 Aug 2019   Prob (F-statistic):           2.03e-31
# Time:                        10:52:18   Log-Likelihood:                -493.33
# No. Observations:                  48   AIC:                             994.7
# Df Residuals:                      44   BIC:                             1002.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    5.91e+04   5916.711      9.988      0.000    4.72e+04     7.1e+04
# ...

# %%
sm.graphics.influence_plot(m1_new)

# %%
print(m1_new.conf_int(0.05))
# Out:
#                       0             1
# Intercept  47174.146254  71022.840413
# x              0.716232      0.862758
# y             -0.151867      0.025169
# z             -0.010376      0.044166

# %%
rq_ml1=smf.ols('x ~ y+z',data=wc1).fit().rsquared

# %%
vif_x=1/(1-rq_ml1)

# %%
vif_x
# Out:
# 2.2509719174188128

# %%
rq_ml2=smf.ols('y ~ x+z',data=wc1).fit().rsquared

# %%
vif_y=1/(1-rq_ml2)

# %%
vif_y
# Out:
# 1.1960162915170802

# %%
rq_ml3=smf.ols('z ~ x+y',data=wc1).fit().rsquared

# %%
vif_z=1/(1-rq_ml3)

# %%
vif_z
# Out:
# 2.229867174093624

# %%
d1={'var':['x','y','z'],'vir':[vif_x,vif_y,vif_z]}

# %%
frame=pd.DataFrame(d1)

# %%
frame
# Out:
#   var       vir
# 0   x  2.250972
# 1   y  1.196016
# 2   z  2.229867

# %%
sm.graphics.plot_partregress_grid(m1_new)

# %%
final=smf.ols('p ~ x+y',data=wc1).fit()
final.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      p   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     559.7
# Date:                Sat, 10 Aug 2019   Prob (F-statistic):           1.62e-32
# Time:                        10:52:21   Log-Likelihood:                -494.17
# No. Observations:                  48   AIC:                             994.3
# Df Residuals:                      45   BIC:                             1000.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   6.273e+04   5182.210     12.106      0.000    5.23e+04    7.32e+04
# ...

# %%
X=wc.iloc[:,:2]

# %%
X
# Out:
#             x          y
# 0   165349.20  136897.80
# 1   162597.70  151377.59
# 2   153441.51  101145.55
# 3   144372.41  118671.85
# 4   142107.34   91391.77
# 5   131876.90   99814.71
# 6   134615.46  147198.87
# 7   130298.13  145530.06
# 8   120542.52  148718.95
# 9   123334.88  108679.17
# 10  101913.08  110594.11
# 11  100671.96   91790.61
# 12   93863.75  127320.38
# 13   91992.39  135495.07
# 14  119943.24  156547.42
# 15  114523.61  122616.84
# 16   78013.11  121597.55
# 17   94657.16  145077.58
# 18   91749.16  114175.79
# 19   86419.70  153514.11
# 20   76253.86  113867.30
# 21   78389.47  153773.43
# 22   73994.56  122782.75
# 23   67532.53  105751.03
# 24   77044.01   99281.34
# 25   64664.71  139553.16
# 26   75328.87  144135.98
# 27   72107.60  127864.55
# 28   66051.52  182645.56
# 29   65605.48  153032.06
# 30   61994.48  115641.28
# 31   61136.38  152701.92
# 32   63408.86  129219.61
# 33   55493.95  103057.49
# 34   46426.07  157693.92
# 35   46014.02   85047.44
# ...

# %%
Y=wc.iloc[:,3:4]

# %%
Y
# Out:
#             p
# 0   192261.83
# 1   191792.06
# 2   191050.39
# 3   182901.99
# 4   166187.94
# 5   156991.12
# 6   156122.51
# 7   155752.60
# 8   152211.77
# 9   149759.96
# 10  146121.95
# 11  144259.40
# 12  141585.52
# 13  134307.35
# 14  132602.65
# 15  129917.04
# 16  126992.93
# 17  125370.37
# 18  124266.90
# 19  122776.86
# 20  118474.03
# 21  111313.02
# 22  110352.25
# 23  108733.99
# 24  108552.04
# 25  107404.34
# 26  105733.54
# 27  105008.31
# 28  103282.38
# 29  101004.64
# 30   99937.59
# 31   97483.56
# 32   97427.84
# 33   96778.92
# 34   96712.80
# 35   96479.51
# 36   90708.19
# 37   89949.14
# 38   81229.06
# 39   81005.76
# 40   78239.91
# 41   77798.83
# 42   71498.49
# 43   69758.98
# 44   65200.33
# 45   64926.08
# 46   49490.75
# 47   42559.73
# 48   35673.41
# 49   14681.40

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size= 0.2, random_state = 0)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (40, 2)
# (10, 2)
# (40, 1)
# (10, 1)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred = reg.predict(X_test)
pred
# Out:
# array([[104573.55181031],
#        [134208.58918288],
#        [135236.7150703 ],
#        [ 72217.56126579],
#        [179149.56875823],
#        [109817.95760936],
#        [ 65718.15366775],
#        [100432.7554212 ],
#        [111433.39381508],
#        [169508.89836922]])

# %%
pred == y_test
# Out:
#         p
# 28  False
# 11  False
# 10  False
# 41  False
# 2   False
# 27  False
# 38  False
# 31  False
# 22  False
# 4   False

# %%
np.mean(pred)
# Out:
# 118229.71449701181

# %%
np.mean(y_test)
# Out:
# p    122277.407
# dtype: float64
