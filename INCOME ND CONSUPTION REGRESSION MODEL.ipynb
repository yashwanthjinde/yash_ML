# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\Narasimha\yashdata\dummy.csv')

# %%
data
# Out:
#     income  consupn Unnamed: 2
# 0      119      154        NaN
# 1       85      123        NaN
# 2       97      125        NaN
# 3       95      130        NaN
# 4      120      151        NaN
# 5       92      131        NaN
# 6      105      141        NaN
# 7      110      141        NaN
# 8       98      130        NaN
# 9       98      134        NaN
# 10      81      115        NaN
# 11      81      117        NaN
# 12      91      123        NaN
# 13     105      144        NaN
# 14     100      137        NaN
# 15     107      140        NaN
# 16      82      123        NaN
# 17      84      115        NaN
# 18     100      134        NaN
# 19     108      147        NaN
# 20     116      144
# 21     115      144        NaN
# 22      93      126        NaN
# 23     105      141        NaN
# 24      89      124        NaN
# 25     104      144        NaN
# 26     108      144        NaN
# 27      88      129        NaN
# 28     109      137        NaN
# ...

# %%
b=data.iloc[:,:2]

# %%
b
# Out:
#     income  consupn
# 0      119      154
# 1       85      123
# 2       97      125
# 3       95      130
# 4      120      151
# 5       92      131
# 6      105      141
# 7      110      141
# 8       98      130
# 9       98      134
# 10      81      115
# 11      81      117
# 12      91      123
# 13     105      144
# 14     100      137
# 15     107      140
# 16      82      123
# 17      84      115
# 18     100      134
# 19     108      147
# 20     116      144
# 21     115      144
# 22      93      126
# 23     105      141
# 24      89      124
# 25     104      144
# 26     108      144
# 27      88      129
# 28     109      137
# 29     112      144
# 30      96      132
# 31      89      125
# 32      93      126
# 33     114      140
# 34      81      120
# 35      84      118
# 36      88      119
# 37      96      131
# 38      82      127
# 39     114      150

# %%
b.head()
# Out:
#    income  consupn
# 0     119      154
# 1      85      123
# 2      97      125
# 3      95      130
# 4     120      151

# %%
sns.pairplot(b)

# %%
import statsmodels.formula.api as smf

# %%
ml1=smf.ols('income ~ consupn',b).fit()
ml1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 income   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     283.6
# Date:                Wed, 07 Aug 2019   Prob (F-statistic):           3.24e-19
# Time:                        22:34:40   Log-Likelihood:                -112.27
# No. Observations:                  40   AIC:                             228.5
# Df Residuals:                      38   BIC:                             231.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -39.1922      8.193     -4.784      0.000     -55.777     -22.607
# ...

# %%
ml2=smf.ols('income ~ np.log(consupn)',b).fit()
ml2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 income   R-squared:                       0.878
# Model:                            OLS   Adj. R-squared:                  0.875
# Method:                 Least Squares   F-statistic:                     274.7
# Date:                Wed, 07 Aug 2019   Prob (F-statistic):           5.55e-19
# Time:                        22:37:22   Log-Likelihood:                -112.83
# No. Observations:                  40   AIC:                             229.7
# Df Residuals:                      38   BIC:                             233.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
ml3=smf.ols('np.log(income) ~ consupn',b).fit()
ml3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         np.log(income)   R-squared:                       0.880
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     278.6
# Date:                Wed, 07 Aug 2019   Prob (F-statistic):           4.39e-19
# Time:                        22:38:49   Log-Likelihood:                 70.854
# No. Observations:                  40   AIC:                            -137.7
# Df Residuals:                      38   BIC:                            -134.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.1810      0.084     37.788      0.000       3.011       3.351
# ...

# %%
ml4=smf.ols('income ~ np.sqrt(consupn)',b).fit()
ml4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 income   R-squared:                       0.881
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     280.1
# Date:                Wed, 07 Aug 2019   Prob (F-statistic):           4.01e-19
# Time:                        22:40:27   Log-Likelihood:                -112.49
# No. Observations:                  40   AIC:                             229.0
# Df Residuals:                      38   BIC:                             232.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
ml5=smf.ols('np.sqrt(income) ~ consupn',b).fit()
ml5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        np.sqrt(income)   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     283.0
# Date:                Wed, 07 Aug 2019   Prob (F-statistic):           3.37e-19
# Time:                        22:41:42   Log-Likelihood:                 7.1933
# No. Observations:                  40   AIC:                            -10.39
# Df Residuals:                      38   BIC:                            -7.009
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9673      0.413      7.178      0.000       2.130       3.804
# ...

# %%
ml2=smf.ols('income ~ np.log(consupn)',b).fit()
ml2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 income   R-squared:                       0.878
# Model:                            OLS   Adj. R-squared:                  0.875
# Method:                 Least Squares   F-statistic:                     274.7
# Date:                Wed, 07 Aug 2019   Prob (F-statistic):           5.55e-19
# Time:                        22:42:38   Log-Likelihood:                -112.83
# No. Observations:                  40   AIC:                             229.7
# Df Residuals:                      38   BIC:                             233.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
x=b.iloc[:,:-1]
x
# Out:
#     income
# 0      119
# 1       85
# 2       97
# 3       95
# 4      120
# 5       92
# 6      105
# 7      110
# 8       98
# 9       98
# 10      81
# 11      81
# 12      91
# 13     105
# 14     100
# 15     107
# 16      82
# 17      84
# 18     100
# 19     108
# 20     116
# 21     115
# 22      93
# 23     105
# 24      89
# 25     104
# 26     108
# 27      88
# 28     109
# 29     112
# 30      96
# 31      89
# 32      93
# 33     114
# 34      81
# 35      84
# 36      88
# 37      96
# 38      82
# 39     114

# %%
y=b.iloc[:,1]
y
# Out:
# 0     154
# 1     123
# 2     125
# 3     130
# 4     151
# 5     131
# 6     141
# 7     141
# 8     130
# 9     134
# 10    115
# 11    117
# 12    123
# 13    144
# 14    137
# 15    140
# 16    123
# 17    115
# 18    134
# 19    147
# 20    144
# 21    144
# 22    126
# 23    141
# 24    124
# 25    144
# 26    144
# 27    129
# 28    137
# 29    144
# 30    132
# 31    125
# 32    126
# 33    140
# 34    120
# 35    118
# 36    119
# 37    131
# 38    127
# 39    150
# Name: consupn, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (32, 1)
# (8, 1)
# (32,)
# (8,)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(regressor.intercept_)
# Out:
# 48.88740409154353

# %%
print(regressor.coef_)
# Out:
# [0.85866253]

# %%
y_pred=regressor.predict(x_test)

# %%
y_pred==y_test
# Out:
# 22    False
# 20    False
# 25    False
# 4     False
# 10    False
# 15    False
# 28    False
# 11    False
# Name: consupn, dtype: bool

# %%
np.mean(y_pred)
# Out:
# 135.93431767688864

# %%
np.mean(y_test)
# Out:
# 134.25

# %%
plt.scatter(x_train,y_train,color='green')
plt.plot(x_train,regressor.predict(x_train),color='red')

# %%
plt.plot(x_train,regressor.predict(x_train),color='green')
plt.scatter(x_test,y_test,color='red')

# %%
plt.plot(x_test,regressor.predict(x_test),color='green')
plt.scatter(x_test,y_test,color='red')

# %%
plt.plot(y_pred,y_test)
plt.scatter(y_pred,y_test,color='green')

# %%
print()
